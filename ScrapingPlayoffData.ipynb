# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
url = "https://www.basketball-reference.com/playoffs/"

# %%
html = urlopen(url)
soup = BeautifulSoup(html, features="lxml")

# %%
headers = [th.getText() for th in soup.findAll('tr', limit=2)[1].findAll('th')]

# %%
headers
# Out:
# ['Year',
#  'Lg',
#  'Champion',
#  'Runner-Up',
#  'Finals MVP',
#  '\xa0',
#  'Points',
#  'Rebounds',
#  'Assists',
#  'Win Shares']

# %%
rows = soup.findAll('tr')[2:]
rows_data = [[td.getText() for td in rows[i].findAll('td')]
                    for i in range(len(rows))]
rows_data.pop(20)
rows_data = rows_data[0:42]

# %%
# we're missing a column for years
# add the years into rows_data
last_year = 2023
for i in range(0, len(rows_data)):
    rows_data[i].insert(0, last_year)
    last_year -=1

# %%
nba_finals = pd.DataFrame(rows_data, columns = headers)
nba_finals.to_csv("nba_finals_history.csv", index=False)

# %%
nba_finals
# Out:
#     Year   Lg               Champion               Runner-Up  \
# 0   2023  NBA         Denver Nuggets              Miami Heat
# 1   2022  NBA  Golden State Warriors          Boston Celtics
# 2   2021  NBA        Milwaukee Bucks            Phoenix Suns
# 3   2020  NBA     Los Angeles Lakers              Miami Heat
# 4   2019  NBA        Toronto Raptors   Golden State Warriors
# 5   2018  NBA  Golden State Warriors     Cleveland Cavaliers
# 6   2017  NBA  Golden State Warriors     Cleveland Cavaliers
# 7   2016  NBA    Cleveland Cavaliers   Golden State Warriors
# 8   2015  NBA  Golden State Warriors     Cleveland Cavaliers
# 9   2014  NBA      San Antonio Spurs              Miami Heat
# 10  2013  NBA             Miami Heat       San Antonio Spurs
# 11  2012  NBA             Miami Heat   Oklahoma City Thunder
# 12  2011  NBA       Dallas Mavericks              Miami Heat
# 13  2010  NBA     Los Angeles Lakers          Boston Celtics
# 14  2009  NBA     Los Angeles Lakers           Orlando Magic
# 15  2008  NBA         Boston Celtics      Los Angeles Lakers
# 16  2007  NBA      San Antonio Spurs     Cleveland Cavaliers
# 17  2006  NBA             Miami Heat        Dallas Mavericks
# 18  2005  NBA      San Antonio Spurs         Detroit Pistons
# 19  2004  NBA        Detroit Pistons      Los Angeles Lakers
# 20  2003  NBA      San Antonio Spurs         New Jersey Nets
# 21  2002  NBA     Los Angeles Lakers         New Jersey Nets
# 22  2001  NBA     Los Angeles Lakers      Philadelphia 76ers
# 23  2000  NBA     Los Angeles Lakers          Indiana Pacers
# 24  1999  NBA      San Antonio Spurs         New York Knicks
# 25  1998  NBA          Chicago Bulls               Utah Jazz
# 26  1997  NBA          Chicago Bulls               Utah Jazz
# 27  1996  NBA          Chicago Bulls     Seattle SuperSonics
# 28  1995  NBA        Houston Rockets           Orlando Magic
# 29  1994  NBA        Houston Rockets         New York Knicks
# 30  1993  NBA          Chicago Bulls            Phoenix Suns
# 31  1992  NBA          Chicago Bulls  Portland Trail Blazers
# 32  1991  NBA          Chicago Bulls      Los Angeles Lakers
# 33  1990  NBA        Detroit Pistons  Portland Trail Blazers
# 34  1989  NBA        Detroit Pistons      Los Angeles Lakers
# 35  1988  NBA     Los Angeles Lakers         Detroit Pistons
# 36  1987  NBA     Los Angeles Lakers          Boston Celtics
# 37  1986  NBA         Boston Celtics         Houston Rockets
# 38  1985  NBA     Los Angeles Lakers          Boston Celtics
# 39  1984  NBA         Boston Celtics      Los Angeles Lakers
# 40  1983                        None                    None
# 41  1982  NBA     Philadelphia 76ers      Los Angeles Lakers
#
#           Finals MVP                        Points                Rebounds  \
# 0           N. Jokić                N. Jokić (600)          N. Jokić (269)
# 1           S. Curry                J. Tatum (615)        A. Horford (214)
# 2   G. Antetokounmpo        G. Antetokounmpo (634)  G. Antetokounmpo (269)
# 3           L. James                A. Davis (582)          L. James (226)
# 4         K. Leonard              K. Leonard (732)          D. Green (223)
# 5          K. Durant                L. James (748)          D. Green (222)
# 6          K. Durant                L. James (591)           K. Love (191)
# 7           L. James             K. Thompson (582)          D. Green (228)
# 8        A. Iguodala                L. James (601)         D. Howard (238)
# 9         K. Leonard               K. Durant (563)         T. Duncan (211)
# 10          L. James                L. James (596)         T. Duncan (214)
# 11          L. James                L. James (697)          L. James (224)
# 12       D. Nowitzki             D. Nowitzki (582)       T. Chandler (193)
# 13         K. Bryant               K. Bryant (671)          P. Gasol (255)
# 14         K. Bryant               K. Bryant (695)         D. Howard (353)
# 15         P. Pierce               K. Bryant (633)        K. Garnett (274)
# 16         T. Parker                L. James (501)         T. Duncan (229)
# 17           D. Wade                 D. Wade (654)       D. Nowitzki (268)
# 18         T. Duncan               T. Duncan (542)         T. Duncan (286)
# 19        C. Billups               K. Bryant (539)        B. Wallace (328)
# 20         T. Duncan               T. Duncan (593)         T. Duncan (369)
# 21         S. O'Neal               S. O'Neal (541)         S. O'Neal (239)
# 22         S. O'Neal              A. Iverson (723)        D. Mutombo (316)
# 23         S. O'Neal               S. O'Neal (707)         S. O'Neal (355)
# 24         T. Duncan             L. Sprewell (407)         T. Duncan (195)
# 25         M. Jordan               M. Jordan (680)         D. Rodman (248)
# 26         M. Jordan               M. Jordan (590)         K. Malone (228)
# 27         M. Jordan               M. Jordan (552)         D. Rodman (247)
# 28       H. Olajuwon             H. Olajuwon (725)         S. O'Neal (250)
# 29       H. Olajuwon             H. Olajuwon (664)          P. Ewing (293)
# 30         M. Jordan               M. Jordan (666)        C. Barkley (326)
# 31         M. Jordan               M. Jordan (759)          H. Grant (194)
# 32         M. Jordan               M. Jordan (529)         D. Rodman (177)
# 33         I. Thomas               M. Jordan (587)       B. Laimbeer (211)
# 34         J. Dumars               M. Jordan (591)         D. Rodman (170)
# 35         J. Worthy               J. Worthy (506)       B. Laimbeer (221)
# 36        M. Johnson                 L. Bird (622)           L. Bird (231)
# 37           L. Bird             H. Olajuwon (537)       H. Olajuwon (236)
# 38   K. Abdul-Jabbar                 L. Bird (520)         R. Parish (219)
# 39           L. Bird                 L. Bird (632)           L. Bird (252)
# 40              None  None                    None                    None
# 41         M. Malone         K. Abdul-Jabbar (406)         M. Malone (206)
#
#                Assists              Win Shares
# 0       N. Jokić (190)          N. Jokić (5.0)
# 1       J. Tatum (148)         J. Butler (3.8)
# 2     J. Holiday (199)  G. Antetokounmpo (3.7)
# 3       L. James (184)          A. Davis (4.5)
# 4       D. Green (187)        K. Leonard (4.9)
# 5       L. James (198)          L. James (5.2)
# 6       L. James (141)          L. James (4.3)
# 7   R. Westbrook (198)          L. James (4.7)
# 8       L. James (169)          S. Curry (3.9)
# 9   R. Westbrook (153)          L. James (4.3)
# 10      L. James (152)          L. James (5.2)
# 11      R. Rondo (227)          L. James (5.8)
# 12       J. Kidd (153)          L. James (3.8)
# 13      R. Rondo (223)          P. Gasol (4.3)
# 14      R. Rondo (137)          L. James (4.8)
# 15      R. Rondo (172)        K. Garnett (4.1)
# 16      L. James (159)          L. James (3.7)
# 17       S. Nash (204)       D. Nowitzki (5.4)
# 18       S. Nash (170)        C. Billups (4.6)
# 19    C. Billups (136)         S. O'Neal (3.9)
# 20       J. Kidd (163)         T. Duncan (5.9)
# 21       J. Kidd (182)         S. O'Neal (3.8)
# 22    A. Iverson (134)         K. Bryant (3.8)
# 23    M. Jackson (178)         S. O'Neal (4.7)
# 24    A. Johnson (126)         T. Duncan (3.7)
# 25   J. Stockton (155)         M. Jordan (4.8)
# 26   J. Stockton (191)         M. Jordan (3.9)
# 27   J. Stockton (195)         M. Jordan (4.7)
# 28   A. Hardaway (162)         S. O'Neal (3.0)
# 29   J. Stockton (157)       H. Olajuwon (4.3)
# 30    K. Johnson (182)        C. Barkley (4.6)
# 31   J. Stockton (217)         M. Jordan (4.1)
# 32    M. Johnson (240)         M. Jordan (4.8)
# 33    K. Johnson (170)         M. Jordan (4.0)
# 34    M. Johnson (165)         M. Jordan (4.0)
# 35    M. Johnson (303)        M. Johnson (4.0)
# 36    M. Johnson (219)        M. Johnson (3.7)
# 37    M. Johnson (211)           L. Bird (4.2)
# 38    M. Johnson (289)        M. Johnson (3.0)
# 39    M. Johnson (284)           L. Bird (4.7)
# 40                None                    None
# 41    M. Johnson (192)         M. Malone (2.8)
